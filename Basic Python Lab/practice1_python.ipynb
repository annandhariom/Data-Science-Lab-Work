# %% [markdown]
#  input in java

# %%
a = input("Enter a")
b = input ("enter b")
# Out:
# Enter a 3
# enter b 4

# %%
a + b
# Out:
# '34'

# %%
int (a) + int (b)
# Out:
# 7

# %% [markdown]
# # operator precedence

# %% [markdown]
# bodmas

# %% [markdown]
# # conditionals

# %%
x = 10

# %%
if (x>500):
    print("greater")
elif(x==100):
    print("100")
else:
    print("smaller")
# Out:
# smaller

# %% [markdown]
# # function

# %%
def greet():
    print("Hello good morning")

# %%
greet()
# Out:
# Hello good morning

# %%
def avg(a= 10, b= 20):
    return (a+b)/2

# %%
avg()
# Out:
# 15.0

# %% [markdown]
# # match case

# %%
code = 404

# %%
match code:
    case 200:
        print("ok")
    case 400:
        print("bad response")
    case 404:
        print("not found")
    case _:
        print("nothing found")

print("end")
# Out:
# nothing found
# end

# %% [markdown]
#  # loop in python

# %%
h = { 1,3,5,7}

# %%
for item in h:
    print(item)

# %%
for i in range(1,10):
    print(i)

# %%
count  = 0
i =1

# %%
while count<10:
    print ( count)
    count = i+1

# %%
#pass statmenet - leave loop get out

# %%
#and break - stops

# %%
# continue - skips current loop

# %% [markdown]
# # list

# %%
l = [1,3,5,6]

# %%
l[0]
